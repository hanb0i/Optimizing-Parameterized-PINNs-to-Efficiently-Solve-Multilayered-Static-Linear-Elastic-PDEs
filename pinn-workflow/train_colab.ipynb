# %%
# !git clone -b reset-changes https://jadelee@github.com/hanb0i/Basic-PiNN-Model-For-Three-Layered-Collision.git
# !git pull origin reset-changes
# Out:
# fatal: destination path 'Basic-PiNN-Model-For-Three-Layered-Collision' already exists and is not an empty directory.
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (5/5), done.
# Unpacking objects: 100% (17/17), 10.28 KiB | 2.57 MiB/s, done.
# remote: Total 17 (delta 12), reused 17 (delta 12), pack-reused 0 (from 0)
# From https://github.com/hanb0i/Basic-PiNN-Model-For-Three-Layered-Collision
#  * branch            reset-changes -> FETCH_HEAD
#    57c8037..0008148  reset-changes -> origin/reset-changes
# Updating 57c8037..0008148
# Fast-forward
#  .../__pycache__/visualization.cpython-314.pyc      | Bin 7094 -> 7149 bytes
#  fea-workflow/postprocessing/visualization.py       |   4 +-
#  fea-workflow/scripts/run_workflow.py               |   2 +-
#  .../solver/__pycache__/fem_solver.cpython-314.pyc  | Bin 9687 -> 11725 bytes
#  pinn-workflow/__pycache__/model.cpython-314.pyc    | Bin 5583 -> 5583 bytes
#  .../__pycache__/pinn_config.cpython-314.pyc        | Bin 1302 -> 1302 bytes
#  pinn-workflow/train_colab.ipynb                    |  59 +--------------------
#  7 files changed, 5 insertions(+), 60 deletions(-)

# %%
import os, sys
from pathlib import Path

repo_root = Path('/content/Basic-PiNN-Model-For-Three-Layered-Collision')
pinn_dir = repo_root / 'pinn-workflow'
sys.path.insert(0, str(pinn_dir))
os.chdir(pinn_dir)

# %%
# !pwd
# !ls
# Out:
# /content/Basic-PiNN-Model-For-Three-Layered-Collision/pinn-workflow
# data.py		  model.py    pinn_config.py  __pycache__  train_colab.ipynb
# fea_solution.npy  physics.py  plot.py	      README.md    train.py

# %%
# %cd /content/Basic-PiNN-Model-For-Three-Layered-Collision
# !ls
# Out:
# /content/Basic-PiNN-Model-For-Three-Layered-Collision
# benchmark_fea.py      diagnostics.py	pinn_model.pth
# compare_results.py    fea_solution.npy	pinn-workflow
# comparison_top.png    fea-workflow	__pycache__
# cross_section.png     loss_curve.png	pyproject.toml
# diagnostic_report.md  loss_history.npy	traction_top_patch.png

# %%
# %cd /content/Basic-PiNN-Model-For-Three-Layered-Collision/fea-workflow/scripts
# !python run_workflow.py
# Out:
# /content/Basic-PiNN-Model-For-Three-Layered-Collision/fea-workflow/scripts
# === Phase 1: Training PINN via pinn-workflow ===
# Using device: cpu
# Starting Adam Training...
# Epoch 0: Total Loss: 96896328.000000 | PDE: 9631980.000000 | BC: 0.000000 | Load: 576.056641 | Interface: 0.203481 | Time: 2.0788s
# Epoch 100: Total Loss: 130344.382812 | PDE: 12955.771484 | BC: 0.000000 | Load: 0.784802 | Interface: 0.006383 | Time: 189.7525s
# Epoch 200: Total Loss: 59253.031250 | PDE: 5887.800781 | BC: 0.000000 | Load: 0.373871 | Interface: 0.004615 | Time: 199.4936s
# Epoch 300: Total Loss: 35454.042969 | PDE: 3521.445557 | BC: 0.000000 | Load: 0.238698 | Interface: 0.004084 | Time: 195.6282s
# Epoch 400: Total Loss: 24091.443359 | PDE: 2392.280273 | BC: 0.000000 | Load: 0.167859 | Interface: 0.004211 | Time: 193.0919s
# Adam Training Complete. Total Time: 971.95s
# Starting L-BFGS Training...
# Running 50 L-BFGS outer steps.
# L-BFGS Step 0: Loss: 17624.513672 | Time: 234.3681s
# L-BFGS Step 1: Loss: 251.243652 | Time: 234.7683s
# L-BFGS Step 2: Loss: 24.596516 | Time: 233.4129s
# L-BFGS Step 3: Loss: 6.737705 | Time: 212.8109s
# Traceback (most recent call last):
#   File "/content/Basic-PiNN-Model-For-Three-Layered-Collision/fea-workflow/scripts/run_workflow.py", line 89, in <module>
#     main()
#   File "/content/Basic-PiNN-Model-For-Three-Layered-Collision/fea-workflow/scripts/run_workflow.py", line 51, in main
#     pinn_model = pinn_train.train()
#                  ^^^^^^^^^^^^^^^^^^
#   File "/content/Basic-PiNN-Model-For-Three-Layered-Collision/pinn-workflow/train.py", line 81, in train
#     loss_val = optimizer_lbfgs.step(closure)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py", line 517, in wrapper
#     out = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 120, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/lbfgs.py", line 330, in step
#     orig_loss = closure()
#                 ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 120, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Basic-PiNN-Model-For-Three-Layered-Collision/pinn-workflow/train.py", line 73, in closure
#     loss_val.backward()
#   File "/usr/local/lib/python3.12/dist-packages/torch/_tensor.py", line 625, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py", line 354, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py", line 841, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
from IPython.display import Image, display

display(Image("loss_curve.png"))
display(Image("displacement_top.png"))
#display(Image("cross_section.png"))

# %%
# %cd
